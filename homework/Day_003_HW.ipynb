# %% [markdown]
# # 在小量的資料上，我們用眼睛就可以看得出來程式碼是否有跑出我們理想中的結果
#
# ## 請嘗試想像一個你需要的資料結構 (裡面的值可以是隨機的)，然後用上述的方法把它變成 pandas DataFrame
#
# ## Ex: 想像一個 dataframe 有兩個欄位，一個是國家，一個是人口，求人口數最多的國家
# ### Hints: 隨機產生數值

# %%
import pandas as pd
import random
import requests
import json
import re

# %%
country_url = 'https://raw.githubusercontent.com/samayo/country-json/master/src/country-by-name.json'
raw_data = json.loads(requests.get(country_url).text)
all_country = [item['country'] for item in raw_data]

df = pd.DataFrame({'country' : random.sample(all_country, 30),
                          'population' : random.sample(range(1000), 30)})
df.sort_values(by = 'population', ascending = False).head(1)
# Out:
#   country  population
# 3    Mali         948

# %% [markdown]
# # 讀取 txt 檔
# 請讀取 text file
#
# 懶人複製連結:
#
# https://raw.githubusercontent.com/vashineyu/slides_and_others/master/tutorial/examples/imagenet_urls_examples.txt
#
# Hints: 使用 Request 抓取資料
#
# Hints: 字串分割
#
# Hints: 例外處理: Try-Except

# %% [markdown]
# ## 將 txt 轉成 pandas dataframe

# %%
target_url = 'https://raw.githubusercontent.com/vashineyu/slides_and_others/master/tutorial/examples/imagenet_urls_examples.txt'
rawdata = requests.get(target_url).text
data = re.split('\t|\n', rawdata)
image_name = list(filter(None, [y for x,y in enumerate(data) if x%2 == 0]))
image_url = list(filter(None, [y for x,y in enumerate(data) if x%2 == 1]))
                       
df = pd.DataFrame({'image_name':image_name, 'image_url':image_url})
df
# Out:
# 9995
# 9995
# ['n00433802_5197', 'n00433802_5202', 'n00433802_5204', 'n00433802_5208', 'n00433802_5211']
# ['http://grfx.cstv.com/photos/schools/afa/sports/m-gym/auto_action/2638217.jpeg', 'http://farm2.static.flickr.com/1130/960179413_0002e006f0.jpg?v=0', 'http://static.flickr.com/150/387324732_f8149d0c65.jpg', 'http://3.bp.blogspot.com/_9T2cRtlgHV0/SK55RHaybXI/AAAAAAAAAwY/VuzoyOGFARQ/s400/Eleni-Andriola-of-Greece4.jpg', 'http://www.loudoungymnastics.com/images/Girls_doing_split%20jpg.jpg']
#           image_name                                          image_url
# 0      n00015388_157  http://farm1.static.flickr.com/145/430300483_2...
# 1      n00015388_238  http://farm2.static.flickr.com/1005/3352960681...
# 2      n00015388_304  http://farm1.static.flickr.com/27/51009336_a96...
# 3      n00015388_327  http://farm4.static.flickr.com/3025/2444687979...
# 4      n00015388_355  http://img100.imageshack.us/img100/3253/forres...
# ...

# %% [markdown]
# ## 讀取圖片，請讀取上面 data frame 中的前 5 張圖片

# %%
from PIL import Image
from io import BytesIO
import matplotlib.pyplot as plt

top5_link = df.loc[0:4, 'image_url'].tolist()
first_link = top5_link[1]
response = requests.get(first_link)

img = BytesIO(response.content)
# plt.imshow(Image.open(img))
# plt.show()


def img2arr_fromURLs(url_list, resize = False):
    numpy_result = []
    for url in url_list:
        try :
            response = requests.get(url)
            img = BytesIO(response.content)
            plt.imshow(Image.open(img))
            numpy_result.append(img)
        except:
            next
    return(numpy_result)

result = img2arr_fromURLs(top5_link)
print('Total image that we got in top 5 is %i' %len(result))
for pic in result:
    plt.imshow(Image.open(pic))
    plt.show
# Out:
# Total image that we got in top 5 is 4
